# %%
# Importing Libraries
import selenium
import pandas as pd
import requests
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains 
from selenium.webdriver.common import keys
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# ## Q 1. Scrape the details of most viewed videos on YouTube from Wikipedia.

# %%
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"

# %%
driver.get(url)

# %%
#scraping names of the video
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No details available')
print(len(name))
# Out:
# 30

# %%
#scraping rank of the video
rank=[]
try:
    ranks=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    rank.append('No details available')
print(len(rank))
# Out:
# 30

# %%
#scraping artist/uploader of the video
artist=[]
try:
    artists=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artists:
        artist.append(i.text)
except NoSuchElementException:#handling no such element exception
    artist.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    artist.append('No details available')
print(len(artist))
# Out:
# 30

# %%
#scraping views of the video
views=[]
try:
    views_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views_list:
        views.append(i.text)
except NoSuchElementException:#handling no such element exception
    views.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    views.append('No details available')
print(len(views))
# Out:
# 30

# %%
#scraping views of the video
upload_date=[]
try:
    upload_date_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date_list:
        upload_date.append(i.text)
except NoSuchElementException:#handling no such element exception
    upload_date.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    upload_date.append('No details available')
print(len(upload_date))
# Out:
# 30

# %%
#preparing dataframe
df = pd.DataFrame({})
df['Rank'] = rank
df['Name'] =  name
df['Artist'] = artist
df['Upload date'] = upload_date
df['Views'] = views
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.  "Learning Colors – Colorful Eggs on a Farm"[22]
# 8    9.                                "Uptown Funk"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                                 "Let Her Go"[41]
# 23  24.                        "Baa Baa Black Sheep"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                               "Shake It Off"[45]
# 27  28.                                    "Perfect"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist        Upload date  Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  10.53
# 1                                    Luis Fonsi   January 12, 2017   7.82
# 2                                   LooLoo Kids    October 8, 2016   6.31
# 3                                    Ed Sheeran   January 30, 2017   5.69
# 4                                   Wiz Khalifa      April 6, 2015   5.48
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018   5.27
# 6                                     ChuChu TV      March 6, 2014   4.58
# 7                                   Miroshka TV  February 27, 2018   4.56
# 8                                   Mark Ronson  November 19, 2014   4.54
# 9                                    Get Movies   January 31, 2012   4.49
# 10                                          Psy      July 15, 2012   4.40
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018   3.96
# 12                                    El Chombo      April 5, 2018   3.92
# 13                                     Maroon 5   January 14, 2015   3.68
# 14                                   Katy Perry  September 5, 2013   3.56
# 15                                  OneRepublic       May 31, 2013   3.56
# 16                                Justin Bieber   October 22, 2015   3.54
# 17                                   Ed Sheeran    October 7, 2014   3.44
# 18                                   Crazy Frog      June 16, 2009   3.32
# 19                                     Maroon 5       May 31, 2018   3.28
# 20                                  Alan Walker   December 3, 2015   3.27
# 21                                   Katy Perry  February 20, 2014   3.26
# 22                                    Passenger      July 25, 2012   3.21
# 23                   Cocomelon – Nursery Rhymes      June 25, 2018   3.21
# 24                             Enrique Iglesias     April 11, 2014   3.19
# 25                                  Major Lazer     March 22, 2015   3.19
# 26                                 Taylor Swift    August 18, 2014   3.16
# 27                                   Ed Sheeran   November 9, 2017   3.14
# 28                                      Shakira       June 4, 2010   3.12
# 29                                     J Balvin      June 29, 2017   3.07

# %% [markdown]
# ## Q 2. Scrape the details team India’s international fixtures from bcci.tv.

# %%
url="https://www.bcci.tv/"

# %%
driver.get(url)

# %%
#going to international fixtures page
fixtures=driver.find_element_by_xpath("/html/body/div[14]/div/div[1]/div[2]/ul[1]/li[2]/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))

# %%
urls=[]
match_page=driver.find_elements_by_xpath("//div[@class='js-list']/a")
for i in match_page:
    urls.append(i.get_attribute('href'))

# %%
match=[]
series=[]
place=[]
date=[]
time=[]
for i in urls:#list of urls of match description pages
    driver.get(i)
    try:#scarping match title
        match_title=driver.find_element_by_xpath("//p[@class='mc-header-info__match-description']/span")
        match.append(match_title.text)
    except NoSuchElementException:#handling no such element exception
        match.append('No details available')
    try:#scarping series title
        series_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']/strong")
        series.append(series_title.text)
    except NoSuchElementException:#handling no such element exception
        series.append("No details Available")
    try:#scarping match venue
        place_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']")
        place.append(place_title.text.split()[-1])
    except NoSuchElementException:#handling no such element exception
        place.append("No details Available")
    try:#scarping date of match 
        date_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/strong")
        date.append(date_title.text)
    except NoSuchElementException:#handling no such element exception
        date.append("No details Available")        
    try:#scarping time of the match
        time_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/span")
        time.append(time_title.text)
    except NoSuchElementException:#handling no such element exception
        time.append("No details Available")

# %%
#preparing dataframe
df = pd.DataFrame({})
df['Match'] = match
df['Series'] = series
df['Place'] = place
df['Date'] = date
df['Time'] = time
df
# Out:
# Empty DataFrame
# Columns: [Match, Series, Place, Date, Time]
# Index: []

# %% [markdown]
# ## Q 3. Scrape the details of selenium exception from guru99.com.

# %%
driver.get('https://www.guru99.com/')

# %%
#clicking on selenium option under testing menu open its tutorial
selenium_link=driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[2]/div/div/div[2]/div/div/a/div[2]")
try:
    selenium_link.click()
except ElementNotInteractableException:#handling element not clickable exception
    driver.get(selenium_link.get_attribute('href'))

# %%
exception_handle_link=driver.find_element_by_xpath("//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handle_link.click()
except ElementNotInteractableException:#handling element not clickable exception
    driver.get(exception_handle_link.get_attribute('href'))

# %%
#scraping exceptions names
name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    for i in names[1:]:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 40

# %%
#scraping exceptions description
desc=[]
try:
    desc_list=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
    for i in desc_list[1:]:
        desc.append(i.text)
except NoSuchElementException:#handling no such element exception
    desc.append('No details available')
print(len(desc))
# Out:
# 40

# %%
#preparing dataframe
df = pd.DataFrame({})
df['Exception_name'] =  name
df['Description'] = desc
df
# Out:
#                          Exception_name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                           Description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# ## Q 4. Scrape the details of State-wise GDP of India from statisticstime.com.

# %%
driver.get("http://statisticstimes.com/")

# %%
#economy button
economy=driver.find_element_by_xpath("/html/body/div[2]/div[1]/div[2]/div[2]/button")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))

# %%
#fetching gdp of india state link
GDP=driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
try:
    GDP.click()
except ElementNotInteractableException:
    driver.get(GDP.get_attribute('href'))

# %%
#scraping rank
rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
print(len(rank))
# Out:
# 33

# %%
#scraping States
State=[]
try:
    states=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in states:
        State.append(i.text)
except NoSuchElementException:#handling no such element exception
    State.append('No details available')
print(len(State))
# Out:
# 33

# %%
#scraping GSDP(18-19)
GSDP_18=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in info:
        GSDP_18.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP_18.append('No details available')
print(len(GSDP_18))
# Out:
# 33

# %%
#scraping GSDP(17-18)
GSDP_17=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in info:
        GSDP_17.append(i.text)
except NoSuchElementException:#handling no such element exception
    GSDP_17.append('No details available')
print(len(GSDP_17))
# Out:
# 33

# %%
#scraping share 2017
share=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in info:
        share.append(i.text)
except NoSuchElementException:#handling no such element exception
    share.append('No details available')
print(len(share))
# Out:
# 33

# %%
#scraping GDP(billion$)
GDP_billion=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in info:
        GDP_billion.append(i.text)
except NoSuchElementException:#handling no such element exception
    GDP_billion.append('No details available')
print(len(GDP_billion))
# Out:
# 33

# %%
#creatng dataframe
df=pd.DataFrame({ })
df['Rank'] =  rank
df['State'] = State
df['GSDP(18-19)'] =GSDP_18
df['GSCP(17-18)'] =GSDP_17
df['Share_2017'] =share
df['GDP(Billion_$)'] =GDP_billion
df
# Out:
#    Rank                      State GSDP(18-19) GSCP(17-18) Share_2017  \
# 0     1                Maharashtra           -   2,632,792     13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208      8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764      8.39%
# 3     4                    Gujarat           -   1,502,899      7.96%
# 4     5                  Karnataka   1,631,977   1,493,127      7.91%
# 5     6                West Bengal   1,253,832   1,089,898      5.77%
# 6     7                  Rajasthan   1,020,989     942,586      4.99%
# 7     8             Andhra Pradesh     972,782     862,957      4.57%
# 8     9                  Telangana     969,604     861,031      4.56%
# 9    10             Madhya Pradesh     906,672     809,592      4.29%
# 10   11                     Kerala           -     781,653      4.14%
# 11   12                      Delhi     856,112     774,870      4.10%
# 12   13                    Haryana     831,610     734,163      3.89%
# 13   14                      Bihar     611,804     530,363      2.81%
# 14   15                     Punjab     574,760     526,376      2.79%
# 15   16                     Odisha     521,275     487,805      2.58%
# 16   17                      Assam           -     315,881      1.67%
# 17   18               Chhattisgarh     329,180     304,063      1.61%
# 18   19                  Jharkhand     328,598     297,204      1.57%
# 19   20                Uttarakhand           -     245,895      1.30%
# 20   21            Jammu & Kashmir           -     155,956      0.83%
# 21   22           Himachal Pradesh     165,472     153,845      0.81%
# 22   23                        Goa      80,449      73,170      0.39%
# 23   24                    Tripura      55,984      49,845      0.26%
# 24   25                 Chandigarh           -      42,114      0.22%
# 25   26                 Puducherry      38,253      34,433      0.18%
# 26   27                  Meghalaya      36,572      33,481      0.18%
# 27   28                     Sikkim      32,496      28,723      0.15%
# 28   29                    Manipur      31,790      27,870      0.15%
# 29   30                   Nagaland           -      27,283      0.14%
# 30   31          Arunachal Pradesh           -      24,603      0.13%
# 31   32                    Mizoram      26,503      22,287      0.12%
# 32   33  Andaman & Nicobar Islands           -           -          -
#
#    GDP(Billion_$)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# 5         165.556
# 6         143.179
# 7         131.083
# 8         130.791
# 9         122.977
# 10        118.733
# 11        117.703
# 12        111.519
# 13         80.562
# 14         79.957
# 15         74.098
# 16         47.982
# 17         46.187
# 18         45.145
# 19         37.351
# 20         23.690
# 21         23.369
# 22         11.115
# 23          7.571
# 24          6.397
# 25          5.230
# 26          5.086
# 27          4.363
# 28          4.233
# 29          4.144
# 30          3.737
# 31          3.385
# 32              -

# %% [markdown]
# ## Q 5. Scrape the details of trending repositories on Github.com.

# %%
driver.get("https://github.com/")

# %%
#finding explore-trending option
explore=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
driver.get(explore.get_attribute('href'))

# %%
#scraping repositories title
repo_title=[]
try:
    repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
    for i in repos:
        repo_title.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_title.append('No details available')

title=repo_title[:20]

# %%
#scraping repositories description
repo_desc=[]
try:
    descriptions=driver.find_elements_by_xpath("//p[@class='col-9 color-fg-muted my-1 pr-4']")
    for i in descriptions:
        repo_desc.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_desc.append('No details available')
Description=repo_desc[:20]

# %%
repo_urls=[]
repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in repos:
    repo_urls.append(i.get_attribute('href'))

# %%
Contributors_count=[]
Language_used=[]
for i in repo_urls:
    driver.get(i)
    l=[]
    try:#scraping contributors count
        count=driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Contributors_count.append(count.text)
    except NoSuchElementException:#handling no such element exception
        Contributors_count.append('No details available')
     #scraping languages used   
    languages=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article[1]/div[2]/span[1]")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    Language_used.append(l)

# %%
Contributors=Contributors_count[:20]
Language=Language_used[:20]

# %%
#creatng dataframe
df=pd.DataFrame({ })
df['Title'] =title
df['Description'] =Description
df['Contributors_count'] =Contributors
df['Language_used'] =Language
df
# Out:
#                                        Title  \
# 0                 facebookresearch / metaseq
# 1          education / GitHubGraduation-2022
# 2                freeCodeCamp / freeCodeCamp
# 3                      scottbez1 / smartknob
# 4                      microsoft / PowerToys
# 5                        pyscript / pyscript
# 6                huggingface / deep-rl-class
# 7                    Dimbreath / GenshinData
# 8        mikeroyal / Digital-Forensics-Guide
# 9                 Grasscutters / Grasscutter
# 10              microsoft / ML-For-Beginners
# 11                       directus / directus
# 12          Azure / MachineLearningNotebooks
# 13               baptixta / game-design-refs
# 14  justjavac / free-programming-books-zh_CN
# 15                             dotnet / docs
# 16                   aptos-labs / aptos-core
# 17                         bhaiest / holoiso
# 18   NginxProxyManager / nginx-proxy-manager
# 19        Azure / azure-quickstart-templates
#
#                                           Description    Contributors_count  \
# 0                  Repo for external large-scale work                     5
# 1   Join the GitHub Graduation Yearbook and "walk ...                 2,069
# 2   freeCodeCamp.org's open-source codebase and cu...                 4,430
# 3   Haptic input knob with software-defined endsto...                     2
# 4   Windows system utilities to maximize productivity                   275
# 5   This repo contain the syllabus of the Hugging ...                    35
# 6   Repository containing the game data for the ga...                     4
# 7                             Digital Forensics Guide  No details available
# 8   A server software reimplementation for a certa...  No details available
# 9   12 weeks, 26 lessons, 52 quizzes, classic Mach...                    26
# 10  The Modern Data Stack 🐰 — Directus is an insta...                   111
# 11  Python notebooks with ML and deep learning exa...                   244
# 12                 🎮 Referências para Game Designers.                    55
# 13                               📚 免费的计算机编程类中文书籍，欢迎投稿                     2
# 14       This repository contains .NET Documentation.                   114
# 15                            A layer 1 for everyone!                 2,090
# 16             SteamOS 3 (Holo) archiso configuration                    38
# 17  Docker container for managing Nginx proxy host...                     3
# 18                         Azure Quickstart Templates                    74
# 19  CVNets: A library for training computer vision...                 1,163
#
#           Language_used
# 0   [No languages used]
# 1   [No languages used]
# 2   [No languages used]
# 3   [No languages used]
# 4   [No languages used]
# 5   [No languages used]
# 6   [No languages used]
# 7   [No languages used]
# 8   [No languages used]
# 9   [No languages used]
# 10  [No languages used]
# 11  [No languages used]
# 12  [No languages used]
# 13  [No languages used]
# 14  [No languages used]
# 15  [No languages used]
# 16  [No languages used]
# 17  [No languages used]
# 18  [No languages used]
# 19  [No languages used]

# %% [markdown]
# ## Q 6. Scrape the details of top 100 songs on billiboard.com.

# %%
driver.get("https://www.billboard.com/")

# %%
#clicking charts button
charts=driver.find_element_by_xpath("/html/body/div[3]/footer/div[4]/div/div/div[2]/div[1]/div[1]/div/nav[3]/ul/li[1]/a")
try:
    charts.click()
except ElementNotInteractableException:
    driver.get(charts.get_attribute('href'))

# %%
#clicking the hot 100 songs link
top_100=driver.find_element_by_xpath('/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a')
try:
    top_100.click()
except ElementNotInteractableException:
    driver.get(top_100.get_attribute('href'))

# %%
#scraping song names
song_name=[]
try:
    names=driver.find_elements_by_xpath('/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div[2]/ul/li[4]/ul/li[1]/h3')
    for i in names:
        song_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    song_name.append('No details available')
print(len(song_name))
# Out:
# 1

# %%
#scraping artist names
artist_name=[]
try:
    names=driver.find_elements_by_xpath('//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div[2]/ul/li[4]/ul/li[1]/span')
    for i in names:
        artist_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    artist_name.append('No details available')
print(len(artist_name))
# Out:
# 1

# %%
#scraping last week rank
last_week_rank=[]
try:
    ranks=driver.find_elements_by_xpath('//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div[4]/ul/li[4]/ul/li[7]/ul/li[3]')
    for i in ranks:
        last_week_rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    last_week_rank.append('No details available')
print(len(last_week_rank))
# Out:
# 1

# %%
#scraping peak rank
peak_rank=[]
try:
    ranks=driver.find_elements_by_xpath('//*[@id="post-1479786"]/div[3]/div/div/div/div[2]/div[2]/ul/li[4]/ul/li[7]/ul/li[4]/span')
    for i in ranks:
        peak_rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    peak_rank.append('No details available')
print(len(peak_rank))
# Out:
# 1

# %%
#scraping weeks on chart
weeks=[]
try:
    week_count=driver.find_elements_by_xpath('/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div[2]/ul/li[4]/ul/li[4]/span')
    for i in week_count:
        weeks.append(i.text)
except NoSuchElementException:#handling no such element exception
    weeks.append('No details available')
print(len(weeks))
# Out:
# 1

# %%
#creating dataframe
df=pd.DataFrame({ })
df['Song_Name']=song_name
df['Artist_Name']=artist_name
df['Last_week_rank']=last_week_rank
df['Peak']=peak_rank
df['Weeks_on_chart']=weeks
df
# Out:
#    Song_Name   Artist_Name Last_week_rank Peak Weeks_on_chart
# 0  As It Was  Harry Styles              3    1

# %% [markdown]
# ## Q 7. Scrape the details of Data science recruiters from naukri.com.

# %%
driver.get("https://www.naukri.com/")

# %%
# finding web element for search job bar using id
search_job =driver.find_element_by_class_name('suggestor-input')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4b800e0bdf76dbdbbbf011fcdba41ac7", element="a302d98c-479c-4841-a4d4-a686a93798f9")>

# %%
# write on search bar
search_job.send_keys('Data Science')

# %%
# clicking using absolute xpath function
search_btn = driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4b800e0bdf76dbdbbbf011fcdba41ac7", element="e5ff1602-b05e-48a0-8826-0ba1a423c734")>

# %%
search_btn.click()

# %%
#clicking on recruiters link
recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))

# %%
#accesing search bar
search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")

# %%
#search button
button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()

# %%
#scrapping names
name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 50

# %%
#scrapping designation
designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        designation.append(i.text)
except NoSuchElementException:#handling no such element exception
    designation.append('No details available')
print(len(designation))
# Out:
# 50

# %%
#scrapping company names
company=[]
try:
    companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in companies:
        company.append(i.text)
except NoSuchElementException:#handling no such element exception
    company.append('No details available')
print(len(company))
# Out:
# 50

# %%
#skills they hire for
skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        skill.append(i.text)
except NoSuchElementException:#handling no such element exception
    skill.append('No details available')
print(len(skill))
# Out:
# 50

# %%
location=[]
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        location.append(i.find('small').text)
    except AttributeError :
        location.append("No details available")
print(len(location))
# Out:
# 50

# %%
#creating dataframe
df=pd.DataFrame({ })
df['Name']=name
df['Designation']=designation
df['Company']=company
df['Location']=location
df['Skills I hire']=skill
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# 18                                  Manisha Yadav
# 19                                    Riya Rajesh
# 20                           Rashmi Bhattacharjee
# 21                                  Faizan Kareem
# 22                                 Rithika dadwal
# 23                             Sandhya Khandagale
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                         Avodha
# 32                                      Jayanth N
# 33                                     Ravi Dubey
# 34                                     Hemant Jog
# 35                                    Priya Khare
# 36                                    Amit Sharma
# 37                                          Kanan
# 38                           Shashikant Chaudhary
# 39                                           Brad
# 40                                   Rutuja Pawar
# 41                            Madhusudhan Sridhar
# 42                                    Ankit Sinha
# 43                                 Gaurav Chouhan
# 44                                   Rashi Kacker
# 45                                        Ashwini
# 46                                   Balaji Kolli
# 47                                 Rajani Nagaraj
# 48                                    ROHIT Kumar
# 49                                 Amir Chowdhury
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Team Lead
# 15                 Assistant Manager HR
# 16                           HR Manager
# 17  Senior Executive Talent Acquisition
# 18                         HR Executive
# 19           Manager Talent Acquisition
# 20                              HR Head
# 21                           HR MANAGER
# 22                         HR Recruiter
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31       Business Development Associate
# 32                      Project Manager
# 33                  Recruitment Manager
# 34                    Company Recruiter
# 35                       Senior Manager
# 36                           Consultant
# 37         senior technology instructor
# 38             HR Recruiter/HR Excutive
# 39        Manager, Technical Recruiting
# 40                  Technical Recruiter
# 41                      Erp Implementer
# 42                       Head Analytics
# 43              Chief Technical Officer
# 44                   Sr Product Manager
# 45             Director Global Delivery
# 46                           Co Founder
# 47                           HR Manager
# 48                            Architect
# 49                     Managing Partner
#
#                                            Company                  Location  \
# 0                             Data Science Network                     Delhi
# 1                    Shore Infotech India Pvt. Ltd  Hyderabad / Secunderabad
# 2                         MARSIAN Technologies LLP                      Pune
# 3            Enerlytics Software Solutions Pvt Ltd                 Ahmedabad
# 4                                  LibraryXProject             UK - (london)
# 5       Apidel Technologies Division of Transpower         Vadodara / Baroda
# 6                                             IFMR                   Chennai
# 7                      Techvantage Systems Pvt Ltd                Trivandrum
# 8                       Weupskill- Live Wire India                    Indore
# 9                 CBL Data Science Private Limited     Bengaluru / Bangalore
# 10                   Infinitive Software Solutions                 Hyderabad
# 11                              Innominds Software  Hyderabad / Secunderabad
# 12                                        MoneyTap     Bengaluru / Bangalore
# 13              QuantMagnum Technologies Pvt. Ltd.                    Mumbai
# 14                               SocialPrachar.com  Hyderabad / Secunderabad
# 15                   BIZ INFOTECNO PRIVATE LIMITED                Chandigarh
# 16                                  BISP Solutions                    Bhopal
# 17                           Bristlecone India Ltd                      Pune
# 18                                        Easi Tax               Navi Mumbai
# 19                     Novelworx Digital Solutions                    Cochin
# 20         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...                     Delhi
# 21                   FirstTech Consaltants Pvt.Ltd  Hyderabad / Secunderabad
# 22                                Affine Analytics                      Pune
# 23                 Compumatrice Multimedia Pvt Ltd                      Pune
# 24                              Exela Technologies                      Pune
# 25                 NEAL ANALYTICS SERVICES PVT LTD                      Pune
# 26      Autumn Leaf Consulting Services Private...     Bengaluru / Bangalore
# 27                                         trainin     Bengaluru / Bangalore
# 28                            Nanoprecise Sci Corp      No details available
# 29                  R.S Consultancy &amp; Services                     Delhi
# 30                                    Confidential     Bengaluru / Bangalore
# 31                              Nikitha Palaparthi  Hyderabad / Secunderabad
# 32        Dollarbird Information Services Pvt, Ltd           Mysoru / Mysore
# 33                     HyrEzy Talent Solutions LLP                 Ghaziabad
# 34                      Hexaware Technologies Ltd.                    Mumbai
# 35                          Independent Consultant     Bengaluru / Bangalore
# 36                                 ASCO consulting                 New Delhi
# 37                                         NY INST                   Chennai
# 38  3D India Staffing Research &amp; Consulting...                   Aligarh
# 39                                     O.C. Tanner            Salt Lake City
# 40                                   Demand Matrix                      Pune
# 41                             MADHUSUDHAN SRIDHAR     Bengaluru / Bangalore
# 42                                  Suntech Global                    Mumbai
# 43                        Strategic Consulting Lab                    Indore
# 44                            Impel Labs Pvt. Ltd.     Bengaluru / Bangalore
# 45                                    MRP Advisers                    MYSORE
# 46                   Saras Solutions India Pvt Ltd  Hyderabad / Secunderabad
# 47                                     WildJasmine     Bengaluru / Bangalore
# 48                             LNT Private Limited                    Mumbai
# 49                                     Granular.ai      No details available
#
#                                         Skills I hire
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Oracle Dba, Data Science, Data Warehousing, ET...
# 11  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 12  Business Intelligence, Data Warehousing, Data ...
# 13  Office Administration, Hr Administration, tele...
# 14  Social Media, digital media maketing, seo, smm...
# 15  React.js, Data Science, Java, Front End, Busin...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 18  Telecalling, Client Interaction, Marketing, Re...
# 19                                       Data Science
# 20  Corporate Sales, Software Development, Softwar...
# 21  Data Analytics, Data Science, Machine Learning...
# 22  Data Science, Machine Learning, Python, R, Dee...
# 23  Big Data, Data Science, Artificial Intelligenc...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Ethical Hacking, Security Operations Center, S...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Walmart Interra Skeps Expressstores indifi whi...
# 34  Big Data, spark, scala, hadoop, hive, Data War...
# 35  Data Science, Artificial Intelligence, analyti...
# 36  Machine Learning, Artificial Intelligence, Dat...
# 37  C, C++, Artificial Intelligence, Python, Php, ...
# 38  Relationship Management, Retail Sales, Private...
# 39                 Data Science, Software Engineering
# 40  Data Science, Big Data Analytics, Digital Mark...
# 41                  Data Science, Recruitment, Salary
# 42  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 43  Software Development, Business Intelligence, B...
# 44                   Data Science, Node.js, Angularjs
# 45  Data Science, Media Marketing, Resource Planni...
# 46  Data Analysis, Learning, Data Science, Compute...
# 47  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 48  Software Development, Core Java, Unit Testing,...
# 49  Machine Learning, Data Science, Product Manage...

# %% [markdown]
# ## Q 8. Scrape the details of Highest selling novels

# %%
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)

# %%
book_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
    for i in names:
        book_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    book_name.append('No details available')
print(len(book_name))
# Out:
# 100

# %%
author_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for i in names:
        author_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    author_name.append('No details available')

print(len(author_name))
# Out:
# 100

# %%
sale=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for i in names:
        sale.append(i.text)
except NoSuchElementException:#handling no such element exception
    sale.append('No details available')

print(len(sale))
# Out:
# 100

# %%
publisher=[]
try:
    publishers=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for i in publishers:
        publisher.append(i.text)
except NoSuchElementException:#handling no such element exception
    publisher.append('No details available')

print(len(publisher))
# Out:
# 100

# %%
genre=[]
try:
    genres=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException:#handling no such element exception
    genre.append('No details available')

print(len(genre))
# Out:
# 100

# %%
df=pd.DataFrame({  })
df['Book_name']= book_name
df['Author_name']= author_name
df['Volume sold']= sale
df['Publisher']= publisher
df['Genre']= genre
df
# Out:
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Q 9. Scrape the details most watched tv series of all time from imdb.com

# %%
url="https://www.imdb.com/list/ls095964455/"

# %%
driver.get(url)
name=[]
try:
    names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    for i in names:
        name.append(i.text)
except NosuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 100

# %%
years=[]
try:
    span=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
    for i in span:
        years.append(i.text)
except NosuchElementException:#handling no such element exception
    years.append('No details available')
print(len(years))
# Out:
# 100

# %%
genre=[]
try:
    genres=driver.find_elements_by_xpath("//span[@class='genre']")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException:#handling no such element exception
    genre.append('No details available')
print(len(genre))
# Out:
# 100

# %%
run_time=[]
try:
    info=driver.find_elements_by_xpath("//span[@class='runtime']")
    for i in info:
        run_time.append(i.text)
except NoSuchElementException:#handling no such element exception
    run_time.append('No details available')
print(len(run_time))
# Out:
# 100

# %%
rating=[]
try:
    info=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
    for i in info:
        rating.append(i.text)
except NoSuchElementException:#handling no such element exception
    rating.append('No details available')
print(len(rating))
# Out:
# 100

# %%
votes=[]
try:
    info=driver.find_elements_by_xpath("//span[@name='nv']")
    for i in info:
        votes.append(i.text)
except NoSuchElementException:#handling no such element exception
    votes.append('No details available')
print(len(votes))
# Out:
# 100

# %%
df=pd.DataFrame({ })
df['Name']=name
df['Years']=years
df['Genre']=genre
df['Run_time']=run_time
df['Rating']=rating
df['Votes']=votes
df
# Out:
#                               Name        Years                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Rating      Votes
# 0    57 min    9.2  1,981,429
# 1    51 min    8.7    987,147
# 2    44 min    8.2    944,260
# 3    60 min    7.5    282,103
# 4    43 min    7.6    241,996
# ..      ...    ...        ...
# 95   42 min    7.4     48,564
# 96   50 min    7.8     59,196
# 97   42 min    8.1    188,903
# 98   45 min    7.1     40,033
# 99  572 min    8.6    226,480
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Q 10. Details of Datasets from UCI machine learning repositories.

# %%
url="https://archive.ics.uci.edu/"

# %%
driver.get(url)

# %%
#clicking show all datasets link
show=driver.find_element_by_xpath("//a[@href='datasets.php']")
show.click()

# %%
#scraping dataset names
name=[]
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
print(len(name))
# Out:
# 622

# %%
#scraping dataset names
data_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
         data_type.append(i.text)
except NoSuchElementException:
    data_type.append("No information")
print(len(data_type))
# Out:
# 622

# %%
#scraping dataset names
default_task=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in info[1:]:
         default_task.append(i.text)
except NoSuchElementException:
    default_task.append("No information")
print(len(default_task))
# Out:
# 622

# %%
#scraping dataset names
attr_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in info[1:]:
         attr_type.append(i.text)
except NoSuchElementException:
    attr_type.append("No information")
print(len(attr_type))
# Out:
# 622

# %%
#scraping dataset names
no_of_instances=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in info[1:]:
         no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append("No information")
print(len(no_of_instances))
# Out:
# 622

# %%
#scraping dataset names
no_of_attributes=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in info[1:]:
         no_of_attributes.append(i.text)
except NoSuchElementException:
    no_of_attributes.append("No information")
print(len(no_of_attributes))
# Out:
# 622

# %%
#scraping dataset names
year=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in info[1:]:
         year.append(i.text)
except NoSuchElementException:
    year.append("No information")
print(len(year))
# Out:
# 622

# %%
#creating dataframe
df=pd.DataFrame({ })
df['Name']=name
df['Data_type']=data_type
df['Task']=default_task
df['Attribute_type']=attr_type
df['No_of_instances']=no_of_instances
df['No_of_attributes']=no_of_attributes
df['Year']=year
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                   Attribute_type No_of_instances No_of_attributes   Year
# 0    Categorical, Integer, Real            4177                8   1995
# 1          Categorical, Integer           48842               14   1996
# 2    Categorical, Integer, Real             798               38
# 3                   Categorical           37711              294   1998
# 4    Categorical, Integer, Real             452              279   1998
# ..                           ...             ...              ...    ...
# 617               Integer, Real           75840              525   2020
# 618               Integer, Real             400               50   2020
# 619                                        1014                7   2020
# 620                        Real           10129               16   2021
# 621                        Real            4000                2   2021
#
# [622 rows x 7 columns]
